# %% [markdown]
# # Mukul Sharma
# This is a Data Analysis Project related to a car dataset.
# Following is the project showing COMPARISON between different attributes of a car and the relation between them.

# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading the Dataset

# %%
df=pd.read_csv('Automobile.csv')
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.describe(include='all')
# Out:
#               name         mpg   cylinders  displacement  horsepower  \
# count          398  398.000000  398.000000    398.000000  392.000000
# unique         305         NaN         NaN           NaN         NaN
# top     ford pinto         NaN         NaN           NaN         NaN
# freq             6         NaN         NaN           NaN         NaN
# mean           NaN   23.514573    5.454774    193.425879  104.469388
# std            NaN    7.815984    1.701004    104.269838   38.491160
# min            NaN    9.000000    3.000000     68.000000   46.000000
# 25%            NaN   17.500000    4.000000    104.250000   75.000000
# 50%            NaN   23.000000    4.000000    148.500000   93.500000
# 75%            NaN   29.000000    8.000000    262.000000  126.000000
# max            NaN   46.600000    8.000000    455.000000  230.000000
#
#              weight  acceleration  model_year origin
# count    398.000000    398.000000  398.000000    398
# unique          NaN           NaN         NaN      3
# top             NaN           NaN         NaN    usa
# freq            NaN           NaN         NaN    249
# mean    2970.424623     15.568090   76.010050    NaN
# std      846.841774      2.757689    3.697627    NaN
# min     1613.000000      8.000000   70.000000    NaN
# 25%     2223.750000     13.825000   73.000000    NaN
# 50%     2803.500000     15.500000   76.000000    NaN
# 75%     3608.000000     17.175000   79.000000    NaN
# max     5140.000000     24.800000   82.000000    NaN

# %% [markdown]
# # Histogram

# %%
sns.histplot(data=df, x='horsepower',bins=20)
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %%
sns.histplot(data=df, x='horsepower',bins=2)
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %% [markdown]
# # Histogram showing the relationship between the count of cars with respective horsepower.

# %%
sns.histplot(data=df, x='horsepower',bins=10)
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %%
sns.histplot(data=df, x='horsepower', kde=True)
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %%
sns.histplot(data=df, x='weight', kde=True)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %%
sns.histplot(data=df, x='acceleration', hue='cylinders', kde=True);

# %%
g = sns.FacetGrid(df, col="cylinders")
g.map(sns.histplot, "acceleration");
# Out:
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data=df, x='horsepower')
# Out:
# <Axes: xlabel='horsepower'>

# %%
sns.boxplot(data=df, x='cylinders', y='horsepower')
# Out:
# <Axes: xlabel='cylinders', ylabel='horsepower'>

# %% [markdown]
# # Boxplot showing the data and outliers for horsepower with respect to cylinders of the cars.

# %% [markdown]
# # BarGraph

# %%
sns.countplot(data=df, x='cylinders');

# %% [markdown]
# # The above data shown is a barplot that describes the count of cars with certain cylinders.

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %%
sns.countplot(data=df, x='cylinders', hue='origin');

# %%
plt.figure(figsize=(50,8))
sns.countplot(data=df,x='horsepower')
plt.show()

# %%
sns.countplot(data=df,x='origin')
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
plt.figure(figsize=(90,20))
sns.countplot(data=df, x='mpg')
plt.xticks(rotation=90)
plt.show()

# %%
plt.title('Histogram: Cylinders')
plt.xlim(0,10)
plt.ylim(0,300)
plt.xlabel('Cylinders')
plt.ylabel('Frequency')
sns.histplot(data=df, x='cylinders', color='red');

# %%
plt.title('Histogram: Acceleration')
plt.xlim(0,30)
plt.ylim(0,80)
plt.xlabel('Accceleration')
plt.ylabel('Frequency')
sns.histplot(data=df, x='acceleration', color='blue');

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %%
plt.figure(figsize=(10,7))
plt.title('Barplot: origin')
plt.ylim(0,150)
plt.xlabel('Origin')
sns.countplot(data=df, x='cylinders', hue='origin');

# %% [markdown]
# # ScatterPlot

# %%
sns.scatterplot(data=df, x='cylinders', y='horsepower');

# %% [markdown]
# # In the above plot the data scattered is shown between the horsepower and the cylinders attributes.

# %%
sns.scatterplot(data=df,x='cylinders',y='weight')
# Out:
# <Axes: xlabel='cylinders', ylabel='weight'>

# %%
sns.scatterplot(data=df,x='cylinders',y='weight',hue='origin')
# Out:
# <Axes: xlabel='cylinders', ylabel='weight'>

# %% [markdown]
# # lmplot(linear model)

# %%
sns.lmplot(data=df,x='weight',y='cylinders')
# Out:
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df,x='weight',y='cylinders',hue='origin')
# Out:
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df,x='weight',y='cylinders',col='origin')
# Out:
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10,7))
sns.stripplot(data=df, x='cylinders', y='weight', hue="origin", jitter=True);

# %% [markdown]
# # ViolinPlot

# %%
sns.violinplot(data=df, x='cylinders',y='horsepower',orient='v');

# %% [markdown]
# # SwarmPlot

# %%
sns.swarmplot(data=df, x='cylinders', y='horsepower');
# Out:
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 30.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 9.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 35.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Catplot

# %%
sns.catplot(data=df, x='cylinders', y ='horsepower', hue='origin', kind='point');
# Out:
# C:\Users\Mukul\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(data=df[['weight','cylinders','horsepower']].corr(),annot=True);

# %% [markdown]
# # The relationship/co-relation between the 3 attributes that are 'weight', 'cylinders', and 'horsepower' is shown with the help of a heatmap.

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\mukul\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mukul\anaconda3\lib\site-packages (from plotly) (8.2.2)

# %%
import plotly.express as px

# %%
pic= px.scatter_3d(df,x='cylinders',y='horsepower',z='acceleration',color='horsepower')
pic.show()
# Out:
# <div>                            <div id="c89718c3-76e7-44ce-8875-9ef014337489" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c89718c3-76e7-44ce-8875-9ef014337489")) {                    Plotly.newPlot(                        "c89718c3-76e7-44ce-8875-9ef014337489",                        [{"hovertemplate":"cylinders=%{x}<br>horsepower=%{marker.color}<br>acceleration=%{z}<extra></extra>","legendgroup":"","marker":{"color":[130.0,165.0,150.0,150.0,140.0,198.0,220.0,215.0,225.0,190.0,170.0,160.0,150.0,225.0,95.0,95.0,97.0,85.0,88.0,46.0,87.0,90.0,95.0,113.0,90.0,215.0,200.0,210.0,193.0,88.0,90.0,95.0,null,100.0,105.0,100.0,88.0,100.0,165.0,175.0,153.0,150.0,180.0,170.0,175.0,110.0,72.0,100.0,88.0,86.0,90.0,70.0,76.0,65.0,69.0,60.0,70.0,95.0,80.0,54.0,90.0,86.0,165.0,175.0,150.0,153.0,150.0,208.0,155.0,160.0,190.0,97.0,150.0,130.0,140.0,150.0,112.0,76.0,87.0,69.0,86.0,92.0,97.0,80.0,88.0,175.0,150.0,145.0,137.0,150.0,198.0,150.0,158.0,150.0,215.0,225.0,175.0,105.0,100.0,100.0,88.0,95.0,46.0,150.0,167.0,170.0,180.0,100.0,88.0,72.0,94.0,90.0,85.0,107.0,90.0,145.0,230.0,49.0,75.0,91.0,112.0,150.0,110.0,122.0,180.0,95.0,null,100.